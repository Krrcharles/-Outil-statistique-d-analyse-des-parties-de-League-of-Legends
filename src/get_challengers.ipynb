# %%
import sqlite3, requests, json, time
import pandas as pd

# %%
api_key = 'RGAPI-85d42f51-8b6d-4c98-afc9-e8a5b0775a6c'

# %%
challengers_url = 'https://euw1.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5'
final_challengers_url = challengers_url + '?api_key=' + api_key

# %%
challengers_data = requests.get(final_challengers_url)
time.sleep(1.2)
joueurs = pd.DataFrame(challengers_data.json()['entries'])
joueurs
# Out:
#                                            summonerId      summonerName  \
# 0    CYi9inPQJ_6FfbMlP92Kdf0RBwuH1VYmsGtgqU-VZ9f86lgr            T1 FSZ
# 1     SAUQa1Tf-cmundUP30CZD2rEFH71u6n2fYfBUa1jUcfF1JE        STEND 2026
# 2    7aKaSHFRX3v2b1tL7K54DfRSZr-fsxMCFMltwmpfgK1OZnte         EUSEUSEUS
# 3     cx5Y41rbI-NXin9wEdKfSHcsoOJQjqgdJokHSNcQpXa2oWU        JG top boy
# 4     CLSvhaSE7EK4uStlIEsfJ_8bsuV8yuhRNlbUcl_fd7Qan74             Shëun
# ..                                                ...               ...
# 295   TB7Ve6-aE6hqsIAYQsW0zB-SBgqmYClKjNF3Fdb3PXfXKio     l will engage
# 296   DGEeYSibge7Qej3eO09_gKqk7wX-iakBf1GqGl3bgt-08KE       BurgerMäker
# 297   L5xFfZN5JjT_jq5ch0NPBdtvkaG1jPBlzVlXI0agrbTGJK0   David Goggins 1
# 298  7JacGVSXeBJ1KVgoEVVuHpyIbLT55VSc5r0DHQt9agVUaF6q    Angel ôf Death
# 299   P7wlM187WR6qedFlGXhBXeGbHj1vfIPAIGRWSJOeZuFkoR8  MARIABECERRA FAN
#
#      leaguePoints rank  wins  losses  veteran  inactive  freshBlood  hotStreak
# 0            1213    I   235     195     True     False       False      False
# 1            1221    I   277     240    False     False       False      False
# 2            1030    I   206     170    False     False        True       True
# 3            1520    I   287     232     True     False       False      False
# 4             987    I   178     123    False     False        True      False
# ..            ...  ...   ...     ...      ...       ...         ...        ...
# 295          1159    I   259     229     True     False       False      False
# 296          1114    I    97      57    False     False       False      False
# 297          1182    I   216     180     True     False       False       True
# 298          1030    I   143     100    False     False       False      False
# 299          1173    I   243     206    False     False       False      False
#
# [300 rows x 10 columns]

# %%
puuid = []
level = []
for id_joueur in joueurs['summonerId']:
    summoner_url = 'https://euw1.api.riotgames.com/lol/summoner/v4/summoners/' + id_joueur + '?api_key=' + api_key
    summoner_data = requests.get(summoner_url).json()
    puuid.append(summoner_data['puuid'])
    level.append(summoner_data['summonerLevel'])
    time.sleep(1.2)

# %%
joueurs['puuid'] = puuid
joueurs['level'] = level
joueurs
# Out:
#                                            summonerId      summonerName  \
# 0    CYi9inPQJ_6FfbMlP92Kdf0RBwuH1VYmsGtgqU-VZ9f86lgr            T1 FSZ
# 1     SAUQa1Tf-cmundUP30CZD2rEFH71u6n2fYfBUa1jUcfF1JE        STEND 2026
# 2    7aKaSHFRX3v2b1tL7K54DfRSZr-fsxMCFMltwmpfgK1OZnte         EUSEUSEUS
# 3     cx5Y41rbI-NXin9wEdKfSHcsoOJQjqgdJokHSNcQpXa2oWU        JG top boy
# 4     CLSvhaSE7EK4uStlIEsfJ_8bsuV8yuhRNlbUcl_fd7Qan74             Shëun
# ..                                                ...               ...
# 295   TB7Ve6-aE6hqsIAYQsW0zB-SBgqmYClKjNF3Fdb3PXfXKio     l will engage
# 296   DGEeYSibge7Qej3eO09_gKqk7wX-iakBf1GqGl3bgt-08KE       BurgerMäker
# 297   L5xFfZN5JjT_jq5ch0NPBdtvkaG1jPBlzVlXI0agrbTGJK0   David Goggins 1
# 298  7JacGVSXeBJ1KVgoEVVuHpyIbLT55VSc5r0DHQt9agVUaF6q    Angel ôf Death
# 299   P7wlM187WR6qedFlGXhBXeGbHj1vfIPAIGRWSJOeZuFkoR8  MARIABECERRA FAN
#
#      leaguePoints rank  wins  losses  veteran  inactive  freshBlood  \
# 0            1213    I   235     195     True     False       False
# 1            1221    I   277     240    False     False       False
# 2            1030    I   206     170    False     False        True
# 3            1520    I   287     232     True     False       False
# 4             987    I   178     123    False     False        True
# ..            ...  ...   ...     ...      ...       ...         ...
# 295          1159    I   259     229     True     False       False
# 296          1114    I    97      57    False     False       False
# 297          1182    I   216     180     True     False       False
# 298          1030    I   143     100    False     False       False
# 299          1173    I   243     206    False     False       False
#
#      hotStreak                                              puuid  level
# 0        False  U6VZgygUjZjYtSegG71z-5cH5LwM334buqlKuxGxWgmvxO...    912
# 1        False  cnk9Di5MKnv2I0dfiDgefnoLDndqUVQRxeVv3i-0Hvzlk6...    509
# 2         True  fXKWiYuwwUPmmLpYgCkkhCCJ6EZhcsE3fwdxipaVWcFlFM...    744
# 3        False  4ltbTnb0922kWuJnZ-MW1uOL6fvVX6mcsYY2J1hzd-iCBo...    741
# 4        False  fDr_DSLyRaq0FSfyv21Y6CiQUqGhFoIXsoN6iUOG_ZGOaB...    260
# ..         ...                                                ...    ...
# 295      False  zNUjgaQMV8Y94KWx6K0GeEJtY-yBrOnsQNdnKdBO6BpanL...    732
# 296      False  TBgq5w6fhXiEdqJaSgXoCEVE0CQnoUxtXvt8cF4_zU7LpB...    498
# 297       True  opCiNF_LGEYPl2O7gZ9luoAfQN3oHHr9JrKh5oZGlJfOSV...    631
# 298      False  mybJzEDSurWd5JQFDmp12Q_x3lKvFpMOhVEAJ-dRBzGsPN...    102
# 299      False  xu53CWoV7UeRAuhvpEOHp97nrZqwbqC0FkLO3GwmHINnT6...   1140
#
# [300 rows x 12 columns]

# %%
matches = []
for puuid_joueur in joueurs['puuid']:
    matches_url = 'https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/' + puuid_joueur +'/ids?type=ranked&start=0&count=20&api_key=' + api_key
    matches_id = requests.get(matches_url).json()
    matches.append(matches_id)
    time.sleep(1.2)

# %%
joueurs['matches'] = matches
joueurs
# Out:
#                                            summonerId      summonerName  \
# 0    CYi9inPQJ_6FfbMlP92Kdf0RBwuH1VYmsGtgqU-VZ9f86lgr            T1 FSZ
# 1     SAUQa1Tf-cmundUP30CZD2rEFH71u6n2fYfBUa1jUcfF1JE        STEND 2026
# 2    7aKaSHFRX3v2b1tL7K54DfRSZr-fsxMCFMltwmpfgK1OZnte         EUSEUSEUS
# 3     cx5Y41rbI-NXin9wEdKfSHcsoOJQjqgdJokHSNcQpXa2oWU        JG top boy
# 4     CLSvhaSE7EK4uStlIEsfJ_8bsuV8yuhRNlbUcl_fd7Qan74             Shëun
# ..                                                ...               ...
# 295   TB7Ve6-aE6hqsIAYQsW0zB-SBgqmYClKjNF3Fdb3PXfXKio     l will engage
# 296   DGEeYSibge7Qej3eO09_gKqk7wX-iakBf1GqGl3bgt-08KE       BurgerMäker
# 297   L5xFfZN5JjT_jq5ch0NPBdtvkaG1jPBlzVlXI0agrbTGJK0   David Goggins 1
# 298  7JacGVSXeBJ1KVgoEVVuHpyIbLT55VSc5r0DHQt9agVUaF6q    Angel ôf Death
# 299   P7wlM187WR6qedFlGXhBXeGbHj1vfIPAIGRWSJOeZuFkoR8  MARIABECERRA FAN
#
#      leaguePoints rank  wins  losses  veteran  inactive  freshBlood  \
# 0            1213    I   235     195     True     False       False
# 1            1221    I   277     240    False     False       False
# 2            1030    I   206     170    False     False        True
# 3            1520    I   287     232     True     False       False
# 4             987    I   178     123    False     False        True
# ..            ...  ...   ...     ...      ...       ...         ...
# 295          1159    I   259     229     True     False       False
# 296          1114    I    97      57    False     False       False
# 297          1182    I   216     180     True     False       False
# 298          1030    I   143     100    False     False       False
# 299          1173    I   243     206    False     False       False
#
#      hotStreak                                              puuid  level  \
# 0        False  U6VZgygUjZjYtSegG71z-5cH5LwM334buqlKuxGxWgmvxO...    912
# 1        False  cnk9Di5MKnv2I0dfiDgefnoLDndqUVQRxeVv3i-0Hvzlk6...    509
# 2         True  fXKWiYuwwUPmmLpYgCkkhCCJ6EZhcsE3fwdxipaVWcFlFM...    744
# 3        False  4ltbTnb0922kWuJnZ-MW1uOL6fvVX6mcsYY2J1hzd-iCBo...    741
# 4        False  fDr_DSLyRaq0FSfyv21Y6CiQUqGhFoIXsoN6iUOG_ZGOaB...    260
# ..         ...                                                ...    ...
# 295      False  zNUjgaQMV8Y94KWx6K0GeEJtY-yBrOnsQNdnKdBO6BpanL...    732
# 296      False  TBgq5w6fhXiEdqJaSgXoCEVE0CQnoUxtXvt8cF4_zU7LpB...    498
# 297       True  opCiNF_LGEYPl2O7gZ9luoAfQN3oHHr9JrKh5oZGlJfOSV...    631
# 298      False  mybJzEDSurWd5JQFDmp12Q_x3lKvFpMOhVEAJ-dRBzGsPN...    102
# 299      False  xu53CWoV7UeRAuhvpEOHp97nrZqwbqC0FkLO3GwmHINnT6...   1140
#
#                                                matches
# 0    [EUW1_6627571462, EUW1_6627524028, EUW1_662748...
# 1    [EUW1_6627913011, EUW1_6627833946, EUW1_662778...
# 2    [EUW1_6627504160, EUW1_6625296610, EUW1_662522...
# 3    [EUW1_6627879600, EUW1_6627722913, EUW1_662768...
# 4    [EUW1_6624723668, EUW1_6624688255, EUW1_662467...
# ..                                                 ...
# 295  [EUW1_6627576227, EUW1_6627440130, EUW1_662738...
# 296  [EUW1_6626771490, EUW1_6626526926, EUW1_662442...
# 297  [EUW1_6624029372, EUW1_6623973145, EUW1_662312...
# 298  [EUW1_6608961762, EUW1_6608883174, EUW1_660882...
# 299  [EUW1_6627879600, EUW1_6627650874, EUW1_662757...
#
# [300 rows x 13 columns]

# %%
# Connect to a database (or create one)
conn = sqlite3.connect('../data/database.db')
joueurs['matches'] = joueurs['matches'].apply(json.dumps)
joueurs.to_sql('joueur', conn, if_exists='replace', index=False)
conn.close()

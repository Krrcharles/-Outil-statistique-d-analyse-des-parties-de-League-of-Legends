# %% [markdown]
# # Exemple utilisation de l'API de LoL

# %% [markdown]
# Les différents liens pouvant être utiles dans le cadre du projet :
#
# API KEY : https://developer.riotgames.com/  -- afin de récupérer votre api key.
#
# DICO API : https://developer.riotgames.com/apis#match-v5/GET_getMatch  -- pour pouvoir voir les différents services à disposition (n'oubliez pas que les services TFT et VL sont pour les jeux Valorant et TFT et ne sont donc pas dans le périmètre du projet).
#
# LIST DATASET : https://developer.riotgames.com/docs/lol#data-dragon_data-assets  -- pour le reste des données, celles non présentes dans les services de l'API, telles les bases champions et items.
#
# ERROR CODE : https://developer.riotgames.com/docs/portal#web-apis_response-codes -- pour vous aider sur la compréhension de potentielles erreurs lors de vos requêtes HTTP auprès de l'API.

# %% [markdown]
# ## Import des modules
#
# requests et json sont les modules nécessaires.
#
# requests : ce module vous permet d'envoyer des requêtes HTTP depuis Python. La requête HTTP renvoie un objet, dans notre cas, sous forme de JSON.

# %%
import requests, json

# %% [markdown]
# Dans le cadre du test, je me permets de mettre en dur l'api_key. Veuillez mettre la vôtre pour vos tests.

# %%
api_key = ''

# %% [markdown]
# ## Récupération des informations de compte
#
# Dans un premier temps nous allons voir comment chercher les informations liées à un utilisateur (en connaisant son nom).

# %% [markdown]
# ### Test sur le compte n°1 du leader EUW

# %%
account_url = 'https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/'
name = 'KC NEXT ADKING'
final_account_url = account_url + name + '?api_key=' + api_key
account_data = requests.get(final_account_url)
account_data.json()
# Out:
# {'id': 'Hr-2CzPvJpSv6ut_SsjsPmB0MlYiwIkUDIlBso9tl__RXPQK',
#  'accountId': 'Z0Pyzgiwv1_pfUUpuqqTxe-HmMWJfKEMr8eXHVgjlPTLvVcValpBEFan',
#  'puuid': 'VtKmyksbtjeXY-O2__4lxlPIDdjNaU7EYXxYbVClzouec6Dhn8xMDOjHnM6EFbyu8GG8teDp3EDLvQ',
#  'name': 'KC NEXT ADKING',
#  'profileIconId': 29,
#  'revisionDate': 1693751153245,
#  'summonerLevel': 430}

# %% [markdown]
# Nous récupérons certaines informations qui pourraient nous êtres utiles par la suite.

# %%
summonerID = account_data.json()['id']
accountID = account_data.json()['accountId']
puuid = account_data.json()['puuid']

# %% [markdown]
# ## Récupération des parties du compte

# %% [markdown]
# A l'aide des informations de compte récupérées précédemment, nous allons chercher ses dernières games.

# %%
list_match_url = 'https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/'
first_game, last_game = 0, 20
final_list_match_url = list_match_url + puuid + '/ids?start=' + str(first_game) + '&' + 'count=' + str(last_game) + '&api_key=' + api_key
list_match_data = requests.get(final_list_match_url)
list_match_data.json()
# Out:
# ['EUW1_6578597295',
#  'EUW1_6578477379',
#  'EUW1_6578422347',
#  'EUW1_6577622236',
#  'EUW1_6577565623',
#  'EUW1_6577501302',
#  'EUW1_6577454386',
#  'EUW1_6577381262',
#  'EUW1_6577348470',
#  'EUW1_6577181071',
#  'EUW1_6577163725',
#  'EUW1_6577133382',
#  'EUW1_6577120734',
#  'EUW1_6577085639',
#  'EUW1_6577069498',
#  'EUW1_6577050534',
#  'EUW1_6575917120',
#  'EUW1_6575876253',
#  'EUW1_6575221345',
#  'EUW1_6575176503']

# %% [markdown]
# Nous récupérons le premier match afin de faire un test dessus par la suite.

# %%
first_match = list_match_data.json()[0]

# %% [markdown]
# ## Récupération des informations d'une partie

# %% [markdown]
# Nous allons regarder dans un premier ce que nous pouvons obtenir comme informations par partie.

# %%
match_url = 'https://europe.api.riotgames.com/lol/match/v5/matches/'
final_match_url = match_url + first_match + '?api_key=' + api_key
match_data = requests.get(final_match_url)
match_data.json()
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'EUW1_6578597295',
#   'participants': ['HOYHts5ZmOOMHyjh9M83jjUqzq18_qqtmWH2Q0GoGjd7Y-xATBmsocb43k0aSWeg7UvNLXN2YEGcKA',
#    'p958aRKLYLdQDSaXtY-nXzUitt2EvRxIt9dciwWJ7mTSmc7t8Lp7rJ0v_Mr9EfYGXUiuqgsdtH2gdg',
#    'qOy_avTF4Ilp5DQae8IzzDtp63OOknDSbRUizIPXErPinaI3jeRHtpE2LravU_Ik3Borq5Zae3oRrQ',
#    'AB7D3feQq9jHuxiKI3NIodcrYHB-Cl0p-U6cCOnBVHbayAgZeRlPx3qpOxvVXfipy9an-99ne4ud_w',
#    'ZSsJmNnq_OYF9eBjxS3hSRkzlPinSBtESMLYatqWYDYURJPwZUxa0c16nC2Qr4Y7p2Q0_zj_Tue_jg',
#    '-cG4SBf7SINEtgCfAkPQ6aAmJwEOEMBB_p4d4QFW1KkJg2g7ujkXuvNYpa2vKahEIu6YpVSF7sHNJw',
#    'VtKmyksbtjeXY-O2__4lxlPIDdjNaU7EYXxYbVClzouec6Dhn8xMDOjHnM6EFbyu8GG8teDp3EDLvQ',
#    'iYAL6C_7DBwlTG-Z-vMWTMP_XFv_lJRbPZPWVxSYS1do1tCg7y2xW243Jxd4ch1y3pM8mCjU7B1RZw',
#    'kLnTHRBm-O8H0g8aC2J3zE7W4TRICUjf9ibQyjOmtKo5qkQgaWybgtyIQqZSdQdD461_UmofGgpLOQ',
#    'YHxjx2-wYO8vRzQQdg-nPEDw_TNT6AqNN_3l_1Z8rjZjj3jecXbGa5Hc7bgsJdQb6LpeM5WV2CmNug']},
#  'info': {'gameCreation': 1693750152684,
#   'gameDuration': 979,
#   'gameEndTimestamp': 1693751145929,
#   'gameId': 6578597295,
#   'gameMode': 'ARAM',
#   'gameName': 'teambuilder-match-6578597295',
#   'gameStartTimestamp': 1693750166724,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '13.17.529.525',
#   'mapId': 12,
#   'participants': [{'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 26,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 6,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 208,
#      'acesBefore15Minutes': 1,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1482.1025081074756,
#      'damageTakenOnTeamPercentage': 0.11928181639250095,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 5,
#      'dodgeSkillShotsSmallWindow': 1,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 1,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 393.25881619999996,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 11,
#      'gameLength': 979.3361225,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 821.5450763496677,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 8,
#      'killAfterHiddenWithAlly': 8,
#      'killParticipation': 0.6451612903225806,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 9,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 13,
#      'laneMinionsFirst10Minutes': 19,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 12,
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 3,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6655,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 3,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 27,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 1,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 9.275361599999997,
#      'skillshotsDodged': 14,
#      'skillshotsHit': 44,
#      'snowballsHit': 5,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 3,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 40,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 3,
#      'takedownsFirstXMinutes': 33,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.21016537725737688,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 1,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 18712,
#     'champLevel': 18,
#     'championId': 145,
#     'championName': 'Kaisa',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 2481,
#     'damageDealtToObjectives': 2481,
#     'damageDealtToTurrets': 2481,
#     'damageSelfMitigated': 8688,
#     'dangerPings': 0,
#     'deaths': 5,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 13409,
#     'goldSpent': 10450,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 7013,
#     'item1': 3040,
#     'item2': 2031,
#     'item3': 0,
#     'item4': 4628,
#     'item5': 3020,
#     'item6': 0,
#     'itemsPurchased': 13,
#     'killingSprees': 3,
#     'kills': 14,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 6,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 231,
#     'magicDamageDealt': 32037,
#     'magicDamageDealtToChampions': 20398,
#     'magicDamageTaken': 9924,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 2033, 'var2': 27, 'var3': 0},
#         {'perk': 8139, 'var1': 884, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 933, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 4689, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 16472,
#     'physicalDamageDealtToChampions': 3394,
#     'physicalDamageTaken': 1900,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4409,
#     'pushPings': 0,
#     'puuid': 'HOYHts5ZmOOMHyjh9M83jjUqzq18_qqtmWH2Q0GoGjd7Y-xATBmsocb43k0aSWeg7UvNLXN2YEGcKA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 63,
#     'spell2Casts': 76,
#     'spell3Casts': 62,
#     'spell4Casts': 7,
#     'subteamPlacement': 0,
#     'summoner1Casts': 14,
#     'summoner1Id': 32,
#     'summoner2Casts': 5,
#     'summoner2Id': 4,
#     'summonerId': 'wvH1T6NNSG-_cH28CKIz-8RzyNolYssSwHV1JnZwhJORV5Y',
#     'summonerLevel': 600,
#     'summonerName': 'Pigfarts',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 0,
#     'timePlayed': 979,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 48983,
#     'totalDamageDealtToChampions': 24191,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 12808,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 1043,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 36,
#     'totalTimeCCDealt': 42,
#     'totalTimeSpentDead': 128,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 473,
#     'trueDamageDealtToChampions': 398,
#     'trueDamageTaken': 984,
#     'turretKills': 1,
#     'turretTakedowns': 3,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 36,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 125,
#      'acesBefore15Minutes': 1,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 450,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 930.6882291197219,
#      'damageTakenOnTeamPercentage': 0.3502861109002024,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 10,
#      'dodgeSkillShotsSmallWindow': 14,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 1635.673583984375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 63,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 393.25881619999996,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 11,
#      'gameLength': 979.3361225,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 739.7766940456136,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 15,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 4.3,
#      'killAfterHiddenWithAlly': 9,
#      'killParticipation': 0.6935483870967742,
#      'killedChampTookFullTeamDamageSurvived': 1,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 2,
#      'landSkillShotsEarlyGame': 11,
#      'laneMinionsFirst10Minutes': 9,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6665,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 29,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 75,
#      'skillshotsHit': 36,
#      'snowballsHit': 10,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 14,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 43,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 4,
#      'takedownsFirstXMinutes': 38,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.1319736264610399,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 1,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17280,
#     'champLevel': 17,
#     'championId': 516,
#     'championName': 'Ornn',
#     'championTransform': 0,
#     'commandPings': 9,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 513,
#     'damageDealtToObjectives': 513,
#     'damageDealtToTurrets': 513,
#     'damageSelfMitigated': 49431,
#     'dangerPings': 0,
#     'deaths': 10,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 1,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12074,
#     'goldSpent': 13065,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3121,
#     'item1': 1011,
#     'item2': 7026,
#     'item3': 3111,
#     'item4': 3068,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 21,
#     'killingSprees': 1,
#     'kills': 7,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 160,
#     'magicDamageDealt': 18034,
#     'magicDamageDealtToChampions': 9337,
#     'magicDamageTaken': 23891,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 1,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5003, 'flex': 5002, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8465, 'var1': 2713, 'var2': 0, 'var3': 0},
#         {'perk': 8463, 'var1': 359, 'var2': 0, 'var3': 0},
#         {'perk': 8429, 'var1': 50, 'var2': 15, 'var3': 13},
#         {'perk': 8451, 'var1': 284, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9105, 'var1': 3, 'var2': 50, 'var3': 0},
#         {'perk': 9111, 'var1': 2939, 'var2': 430, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 15127,
#     'physicalDamageDealtToChampions': 4953,
#     'physicalDamageTaken': 9281,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 3502,
#     'pushPings': 0,
#     'puuid': 'p958aRKLYLdQDSaXtY-nXzUitt2EvRxIt9dciwWJ7mTSmc7t8Lp7rJ0v_Mr9EfYGXUiuqgsdtH2gdg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 53,
#     'spell2Casts': 28,
#     'spell3Casts': 30,
#     'spell4Casts': 14,
#     'subteamPlacement': 0,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 19,
#     'summoner2Id': 32,
#     'summonerId': 'xip7w-w0P5wZQY7WKaaCGwe3SWeV2Km7StV3XZjXRpPpgjQ',
#     'summonerLevel': 465,
#     'summonerName': 'Raynors Raiders',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 41,
#     'timePlayed': 979,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 34061,
#     'totalDamageDealtToChampions': 15190,
#     'totalDamageShieldedOnTeammates': 1480,
#     'totalDamageTaken': 37614,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 6368,
#     'totalHealsOnTeammates': 154,
#     'totalMinionsKilled': 18,
#     'totalTimeCCDealt': 238,
#     'totalTimeSpentDead': 232,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 900,
#     'trueDamageDealtToChampions': 900,
#     'trueDamageTaken': 4441,
#     'turretKills': 0,
#     'turretTakedowns': 3,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 24,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 175,
#      'acesBefore15Minutes': 1,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1390.7788446121572,
#      'damageTakenOnTeamPercentage': 0.15451724685995266,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 10,
#      'dodgeSkillShotsSmallWindow': 5,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 383.7026062011719,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 12,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 393.25881619999996,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 11,
#      'gameLength': 979.3361225,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 752.2813584298787,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 3,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 3.7,
#      'killAfterHiddenWithAlly': 12,
#      'killParticipation': 0.5967741935483871,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 3,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 8,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 20,
#      'laneMinionsFirst10Minutes': 31,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 20,
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 1,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6691,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 26,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 1,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 21.4344476,
#      'skillshotsDodged': 30,
#      'skillshotsHit': 43,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 2,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 37,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 4,
#      'takedownsFirstXMinutes': 33,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.19721548203351186,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 1,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 15965,
#     'champLevel': 16,
#     'championId': 222,
#     'championName': 'Jinx',
#     'championTransform': 0,
#     'commandPings': 6,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 3941,
#     'damageDealtToObjectives': 3941,
#     'damageDealtToTurrets': 3941,
#     'damageSelfMitigated': 4913,
#     'dangerPings': 0,
#     'deaths': 10,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': True,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12278,
#     'goldSpent': 11400,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3042,
#     'item1': 6691,
#     'item2': 6676,
#     'item3': 3158,
#     'item4': 3035,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 20,
#     'killingSprees': 4,
#     'kills': 13,
#     'lane': 'NONE',
#     'largestCriticalStrike': 352,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 159,
#     'magicDamageDealt': 1943,
#     'magicDamageDealtToChampions': 885,
#     'magicDamageTaken': 14582,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1413, 'var2': 26, 'var3': 0},
#         {'perk': 8126, 'var1': 455, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8009, 'var1': 3787, 'var2': 0, 'var3': 0},
#         {'perk': 8014, 'var1': 794, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 54189,
#     'physicalDamageDealtToChampions': 21384,
#     'physicalDamageTaken': 1566,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5800,
#     'pushPings': 0,
#     'puuid': 'qOy_avTF4Ilp5DQae8IzzDtp63OOknDSbRUizIPXErPinaI3jeRHtpE2LravU_Ik3Borq5Zae3oRrQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 58,
#     'spell2Casts': 80,
#     'spell3Casts': 22,
#     'spell4Casts': 15,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 7,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'qfnM90ZbNpQlNREz7R5dJytjjMRHYv-06Rk0dmDcdBdh7f4',
#     'summonerLevel': 400,
#     'summonerName': 'ODB KenShin',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 25,
#     'timePlayed': 979,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 56562,
#     'totalDamageDealtToChampions': 22700,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 16592,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 1401,
#     'totalHealsOnTeammates': 383,
#     'totalMinionsKilled': 43,
#     'totalTimeCCDealt': 68,
#     'totalTimeSpentDead': 230,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 430,
#     'trueDamageDealtToChampions': 430,
#     'trueDamageTaken': 443,
#     'turretKills': 1,
#     'turretTakedowns': 3,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 36,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 2,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 206,
#      'acesBefore15Minutes': 1,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 600,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1257.3972735418017,
#      'damageTakenOnTeamPercentage': 0.15146765685331365,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 4,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 7,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 393.25881619999996,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 11,
#      'gameLength': 979.3361225,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 743.2397184004107,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 4,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 2,
#      'kda': 5.625,
#      'killAfterHiddenWithAlly': 4,
#      'killParticipation': 0.7258064516129032,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 4,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 2,
#      'landSkillShotsEarlyGame': 18,
#      'laneMinionsFirst10Minutes': 11,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6692,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 33,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 1,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 9.275361599999997,
#      'skillshotsDodged': 24,
#      'skillshotsHit': 32,
#      'snowballsHit': 5,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 45,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 4,
#      'takedownsFirstXMinutes': 40,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.1783016835277812,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17934,
#     'champLevel': 17,
#     'championId': 126,
#     'championName': 'Jayce',
#     'championTransform': 0,
#     'commandPings': 12,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 3312,
#     'damageDealtToObjectives': 3312,
#     'damageDealtToTurrets': 3312,
#     'damageSelfMitigated': 7608,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': True,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12131,
#     'goldSpent': 9400,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3042,
#     'item1': 6692,
#     'item2': 3071,
#     'item3': 1001,
#     'item4': 0,
#     'item5': 0,
#     'item6': 0,
#     'itemsPurchased': 14,
#     'killingSprees': 2,
#     'kills': 9,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 277,
#     'magicDamageDealt': 2377,
#     'magicDamageDealtToChampions': 2186,
#     'magicDamageTaken': 12384,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1556, 'var2': 27, 'var3': 0},
#         {'perk': 8126, 'var1': 395, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9105, 'var1': 3, 'var2': 20, 'var3': 0},
#         {'perk': 8014, 'var1': 601, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 30844,
#     'physicalDamageDealtToChampions': 17487,
#     'physicalDamageTaken': 3071,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5907,
#     'pushPings': 0,
#     'puuid': 'AB7D3feQq9jHuxiKI3NIodcrYHB-Cl0p-U6cCOnBVHbayAgZeRlPx3qpOxvVXfipy9an-99ne4ud_w',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 61,
#     'spell2Casts': 61,
#     'spell3Casts': 59,
#     'spell4Casts': 25,
#     'subteamPlacement': 0,
#     'summoner1Casts': 2,
#     'summoner1Id': 4,
#     'summoner2Casts': 11,
#     'summoner2Id': 32,
#     'summonerId': 'jxuH4Rw9TBEQxxIyVEzdT0vDqeuRFYYPBgKqpmd-oc9b7mI',
#     'summonerLevel': 699,
#     'summonerName': 'ODB Swifty',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 4,
#     'timePlayed': 979,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 34180,
#     'totalDamageDealtToChampions': 20523,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 16265,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 1391,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 18,
#     'totalTimeCCDealt': 21,
#     'totalTimeSpentDead': 154,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 958,
#     'trueDamageDealtToChampions': 850,
#     'trueDamageTaken': 809,
#     'turretKills': 1,
#     'turretTakedowns': 4,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 28,
#     'baitPings': 1,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 2,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 306,
#      'acesBefore15Minutes': 1,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 450,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1991.110548845297,
#      'damageTakenOnTeamPercentage': 0.22444716899403036,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 12,
#      'dodgeSkillShotsSmallWindow': 6,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 393.25881619999996,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 11,
#      'gameLength': 979.3361225,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 937.8550340360799,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.9166666666666665,
#      'killAfterHiddenWithAlly': 10,
#      'killParticipation': 0.7580645161290323,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 9,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 2,
#      'killsUnderOwnTurret': 7,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 43,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 54,
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 3,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 5,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6653,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 4,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 33,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 9.275361599999997,
#      'skillshotsDodged': 33,
#      'skillshotsHit': 8,
#      'snowballsHit': 8,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 5,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 47,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 4,
#      'takedownsFirstXMinutes': 42,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.2823438307202902,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 3,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17883,
#     'champLevel': 17,
#     'championId': 30,
#     'championName': 'Karthus',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 1188,
#     'damageDealtToObjectives': 1188,
#     'damageDealtToTurrets': 1188,
#     'damageSelfMitigated': 7662,
#     'dangerPings': 0,
#     'deaths': 12,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 5,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 15307,
#     'goldSpent': 13085,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 7012,
#     'item1': 4645,
#     'item2': 3020,
#     'item3': 3916,
#     'item4': 3089,
#     'item5': 4630,
#     'item6': 2052,
#     'itemsPurchased': 15,
#     'killingSprees': 6,
#     'kills': 19,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 100,
#     'magicDamageDealt': 83249,
#     'magicDamageDealtToChampions': 30602,
#     'magicDamageTaken': 18194,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8369, 'var1': 1082, 'var2': 791, 'var3': 0},
#         {'perk': 8304, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8321, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 145,
#     'physicalDamageDealtToChampions': 41,
#     'physicalDamageTaken': 4338,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5410,
#     'pushPings': 0,
#     'puuid': 'ZSsJmNnq_OYF9eBjxS3hSRkzlPinSBtESMLYatqWYDYURJPwZUxa0c16nC2Qr4Y7p2Q0_zj_Tue_jg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 228,
#     'spell2Casts': 31,
#     'spell3Casts': 42,
#     'spell4Casts': 5,
#     'subteamPlacement': 0,
#     'summoner1Casts': 2,
#     'summoner1Id': 4,
#     'summoner2Casts': 21,
#     'summoner2Id': 32,
#     'summonerId': 'nyzSpyEUX_IMTnt4PE_fOHuRfaCU8v7bbt61HO5vhkQckZY',
#     'summonerLevel': 574,
#     'summonerName': 'Razorlike',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 26,
#     'timePlayed': 979,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 85456,
#     'totalDamageDealtToChampions': 32499,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 24101,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 526,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 78,
#     'totalTimeCCDealt': 412,
#     'totalTimeSpentDead': 282,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2061,
#     'trueDamageDealtToChampions': 1855,
#     'trueDamageTaken': 1568,
#     'turretKills': 1,
#     'turretTakedowns': 2,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 16,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 115,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 525,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1067.9910630606807,
#      'damageTakenOnTeamPercentage': 0.1889829574853932,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 13,
#      'dodgeSkillShotsSmallWindow': 7,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 51,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 979.3361225,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 637.5866930074358,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 15,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.8461538461538463,
#      'killAfterHiddenWithAlly': 11,
#      'killParticipation': 0.5333333333333333,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 3,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 20,
#      'laneMinionsFirst10Minutes': 14,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 2,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6655,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 18,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 36,
#      'skillshotsHit': 41,
#      'snowballsHit': 4,
#      'soloBaronKills': 0,
#      'soloKills': 2,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 24,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 2,
#      'takedownsFirstXMinutes': 24,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.17089378220323143,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 14102,
#     'champLevel': 15,
#     'championId': 518,
#     'championName': 'Neeko',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 455,
#     'damageDealtToObjectives': 455,
#     'damageDealtToTurrets': 455,
#     'damageSelfMitigated': 9818,
#     'dangerPings': 0,
#     'deaths': 13,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 10406,
#     'goldSpent': 9800,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6655,
#     'item1': 3020,
#     'item2': 4645,
#     'item3': 1058,
#     'item4': 1058,
#     'item5': 0,
#     'item6': 0,
#     'itemsPurchased': 13,
#     'killingSprees': 3,
#     'kills': 8,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 162,
#     'magicDamageDealt': 33029,
#     'magicDamageDealtToChampions': 16190,
#     'magicDamageTaken': 13545,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 6,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 777, 'var2': 16, 'var3': 0},
#         {'perk': 8126, 'var1': 592, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8226, 'var1': 250, 'var2': 167, 'var3': 0},
#         {'perk': 8210, 'var1': 15, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 996,
#     'physicalDamageDealtToChampions': 359,
#     'physicalDamageTaken': 9146,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 3159,
#     'pushPings': 0,
#     'puuid': '-cG4SBf7SINEtgCfAkPQ6aAmJwEOEMBB_p4d4QFW1KkJg2g7ujkXuvNYpa2vKahEIu6YpVSF7sHNJw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 39,
#     'spell2Casts': 37,
#     'spell3Casts': 31,
#     'spell4Casts': 8,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 13,
#     'summoner2Id': 32,
#     'summonerId': 'Uhc1s4xSj6qfIG1GzZcLAZDXKelTKs_maXFWBIPXgHCZehg',
#     'summonerLevel': 344,
#     'summonerName': 'Noïx de Coco',
#     'teamEarlySurrendered': False,
# ...
#      'damageTakenOnTeamPercentage': 0.17234636288506552,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 12,
#      'dodgeSkillShotsSmallWindow': 5,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 12,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 979.3361225,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 615.942327106902,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 6,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2,
#      'killAfterHiddenWithAlly': 13,
#      'killParticipation': 0.5333333333333333,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 6,
#      'landSkillShotsEarlyGame': 28,
#      'laneMinionsFirst10Minutes': 17,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 2,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6655,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 17,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 30,
#      'skillshotsHit': 50,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 1,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 24,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 2,
#      'takedownsFirstXMinutes': 24,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.15630983749175145,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 14504,
#     'champLevel': 15,
#     'championId': 161,
#     'championName': 'Velkoz',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 0,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 10079,
#     'dangerPings': 0,
#     'deaths': 12,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 1,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 10053,
#     'goldSpent': 9150,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6655,
#     'item1': 3020,
#     'item2': 3089,
#     'item3': 4630,
#     'item4': 0,
#     'item5': 0,
#     'item6': 0,
#     'itemsPurchased': 10,
#     'killingSprees': 0,
#     'kills': 4,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 120,
#     'magicDamageDealt': 31567,
#     'magicDamageDealtToChampions': 12282,
#     'magicDamageTaken': 12767,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1158, 'var2': 23, 'var3': 0},
#         {'perk': 8126, 'var1': 612, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 300, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 2497, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 1627,
#     'physicalDamageDealtToChampions': 250,
#     'physicalDamageTaken': 8027,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5254,
#     'pushPings': 0,
#     'puuid': 'kLnTHRBm-O8H0g8aC2J3zE7W4TRICUjf9ibQyjOmtKo5qkQgaWybgtyIQqZSdQdD461_UmofGgpLOQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 62,
#     'spell2Casts': 50,
#     'spell3Casts': 22,
#     'spell4Casts': 7,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 0,
#     'summoner2Id': 13,
#     'summonerId': 'Cv1jvPJ5IznvTn_RmpPo0B1zgd0-nK5NI4tl2SSz6CBB0-g7',
#     'summonerLevel': 195,
#     'summonerName': 'Zohraz',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 20,
#     'timePlayed': 979,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 38258,
#     'totalDamageDealtToChampions': 15944,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 21321,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 1560,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 26,
#     'totalTimeCCDealt': 156,
#     'totalTimeSpentDead': 270,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 5064,
#     'trueDamageDealtToChampions': 3411,
#     'trueDamageTaken': 526,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 12,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 129,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 900,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1481.9863181090823,
#      'damageTakenOnTeamPercentage': 0.2074216815625042,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 15,
#      'dodgeSkillShotsSmallWindow': 5,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 28,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 979.3361225,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 759.0110448455862,
#      'hadOpenNexus': 0,
#      'highestCrowdControlScore': 1,
#      'immobilizeAndKillWithAlly': 11,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.7333333333333334,
#      'killAfterHiddenWithAlly': 6,
#      'killParticipation': 0.5777777777777777,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 5,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 26,
#      'laneMinionsFirst10Minutes': 28,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 11,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 1,
#      'mythicItemUsed': 6655,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 3,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 17,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 32,
#      'skillshotsHit': 42,
#      'snowballsHit': 9,
#      'soloBaronKills': 0,
#      'soloKills': 2,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 26,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 2,
#      'takedownsFirstXMinutes': 26,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.23713891982325752,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 1,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 15563,
#     'champLevel': 16,
#     'championId': 127,
#     'championName': 'Lissandra',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 232,
#     'damageDealtToObjectives': 232,
#     'damageDealtToTurrets': 232,
#     'damageSelfMitigated': 12204,
#     'dangerPings': 0,
#     'deaths': 15,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12388,
#     'goldSpent': 11350,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6655,
#     'item1': 3157,
#     'item2': 3135,
#     'item3': 3020,
#     'item4': 1058,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 15,
#     'killingSprees': 3,
#     'kills': 14,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 107,
#     'magicDamageDealt': 50766,
#     'magicDamageDealtToChampions': 22184,
#     'magicDamageTaken': 13933,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1448, 'var2': 24, 'var3': 0},
#         {'perk': 8126, 'var1': 784, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8009, 'var1': 2734, 'var2': 0, 'var3': 0},
#         {'perk': 8014, 'var1': 714, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 890,
#     'physicalDamageDealtToChampions': 410,
#     'physicalDamageTaken': 10942,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5126,
#     'pushPings': 0,
#     'puuid': 'YHxjx2-wYO8vRzQQdg-nPEDw_TNT6AqNN_3l_1Z8rjZjj3jecXbGa5Hc7bgsJdQb6LpeM5WV2CmNug',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 40,
#     'spell2Casts': 32,
#     'spell3Casts': 43,
#     'spell4Casts': 14,
#     'subteamPlacement': 0,
#     'summoner1Casts': 17,
#     'summoner1Id': 32,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'HquuoH1w1uJyjlixhVdTqDfaULhveo7949N9ke2VSmb1HKg',
#     'summonerLevel': 257,
#     'summonerName': 'DevaCifer',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 42,
#     'timePlayed': 979,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 53331,
#     'totalDamageDealtToChampions': 24189,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 25660,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 959,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 40,
#     'totalTimeCCDealt': 325,
#     'totalTimeSpentDead': 320,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 1675,
#     'trueDamageDealtToChampions': 1595,
#     'trueDamageTaken': 783,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False}],
#   'platformId': 'EUW1',
#   'queueId': 450,
#   'teams': [{'bans': [],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 62},
#      'dragon': {'first': False, 'kills': 0},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 4}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': True, 'kills': 45},
#      'dragon': {'first': False, 'kills': 0},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 0}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}

# %% [markdown]
# N'hésitez pas à copier-coller la sortie dans un éditeur de texte afin de pouvoir décortiquer le json et pouvoir repérer facilement les informations qui vous intéressent.
#
# Nous pouvons remarquer que dans "info" nous avons "participants", une liste de longueur 10. Nous allons récupèrer quelques données pour le premier joueur.

# %%
joueur1 = [
        match_data.json()['info']['participants'][0]['summonerName'], match_data.json()['info']['participants'][0]['summonerId'], match_data.json()['info']['participants'][0]['puuid'],
        match_data.json()['info']['participants'][0]['championName'], match_data.json()['info']['participants'][0]['lane'], match_data.json()['info']['participants'][0]['role'],
        match_data.json()['info']['participants'][0]['kills'], match_data.json()['info']['participants'][0]['deaths'], match_data.json()['info']['participants'][0]['assists'],  
        match_data.json()['info']['participants'][0]['perks']['styles'][0]['style'], match_data.json()['info']['participants'][0]['perks']['styles'][0]['selections'][0]['perk'],
        match_data.json()['info']['participants'][0]['teamId'], match_data.json()['info']['participants'][0]['win']
        ]
print(joueur1)
# Out:
# ['Pigfarts', 'wvH1T6NNSG-_cH28CKIz-8RzyNolYssSwHV1JnZwhJORV5Y', 'HOYHts5ZmOOMHyjh9M83jjUqzq18_qqtmWH2Q0GoGjd7Y-xATBmsocb43k0aSWeg7UvNLXN2YEGcKA', 'Kaisa', 'NONE', 'SUPPORT', 14, 5, 26, 8100, 8128, 100, True]

# %% [markdown]
# ## Récupération et stockage de l'ensemble des parties

# %% [markdown]
# Maintenant que nous avons pu regarder les différentes données présentes, nous allons récupérer un lot d'informations par match, sur l'ensemble des matchs.
#
# Pour cela nous créons notre match_database avec l'entête.

# %%
match_database = [['matchId', 'gameMode', 'mapId']]
for k in range(1, 11):
    match_database[0].append([f'J{k}_summonerName', f'J{k}_summonerId', f'J{k}_puuid', f'J{k}_championId', f'J{k}_championName', f'J{k}_lane', f'J{k}_role', f'J{k}_kills', f'J{k}_deaths', f'J{k}_assists', 
                         f'J{k}_summonerSpell1', f'J{k}_summonerSpell2',
                         f'J{k}_primaryStyle', f'J{k}_primaryStyle1', f'J{k}_primaryStyle2', f'J{k}_primaryStyle3', f'J{k}_primaryStyle4', f'J{k}_subStyle', f'J{k}_subStyle1', f'J{k}_subStyle2',
                         f'J{k}_item1', f'J{k}_item2', f'J{k}_item3', f'J{k}_item4', f'J{k}_item5', f'J{k}_item6', f'J{k}_item7', 
                         f'J{k}_teamId', f'J{k}_win'])
print(match_database)
# Out:
# [['matchId', 'gameMode', 'mapId', ['J1_summonerName', 'J1_summonerId', 'J1_puuid', 'J1_championId', 'J1_championName', 'J1_lane', 'J1_role', 'J1_kills', 'J1_deaths', 'J1_assists', 'J1_summonerSpell1', 'J1_summonerSpell2', 'J1_primaryStyle', 'J1_primaryStyle1', 'J1_primaryStyle2', 'J1_primaryStyle3', 'J1_primaryStyle4', 'J1_subStyle', 'J1_subStyle1', 'J1_subStyle2', 'J1_item1', 'J1_item2', 'J1_item3', 'J1_item4', 'J1_item5', 'J1_item6', 'J1_item7', 'J1_teamId', 'J1_win'], ['J2_summonerName', 'J2_summonerId', 'J2_puuid', 'J2_championId', 'J2_championName', 'J2_lane', 'J2_role', 'J2_kills', 'J2_deaths', 'J2_assists', 'J2_summonerSpell1', 'J2_summonerSpell2', 'J2_primaryStyle', 'J2_primaryStyle1', 'J2_primaryStyle2', 'J2_primaryStyle3', 'J2_primaryStyle4', 'J2_subStyle', 'J2_subStyle1', 'J2_subStyle2', 'J2_item1', 'J2_item2', 'J2_item3', 'J2_item4', 'J2_item5', 'J2_item6', 'J2_item7', 'J2_teamId', 'J2_win'], ['J3_summonerName', 'J3_summonerId', 'J3_puuid', 'J3_championId', 'J3_championName', 'J3_lane', 'J3_role', 'J3_kills', 'J3_deaths', 'J3_assists', 'J3_summonerSpell1', 'J3_summonerSpell2', 'J3_primaryStyle', 'J3_primaryStyle1', 'J3_primaryStyle2', 'J3_primaryStyle3', 'J3_primaryStyle4', 'J3_subStyle', 'J3_subStyle1', 'J3_subStyle2', 'J3_item1', 'J3_item2', 'J3_item3', 'J3_item4', 'J3_item5', 'J3_item6', 'J3_item7', 'J3_teamId', 'J3_win'], ['J4_summonerName', 'J4_summonerId', 'J4_puuid', 'J4_championId', 'J4_championName', 'J4_lane', 'J4_role', 'J4_kills', 'J4_deaths', 'J4_assists', 'J4_summonerSpell1', 'J4_summonerSpell2', 'J4_primaryStyle', 'J4_primaryStyle1', 'J4_primaryStyle2', 'J4_primaryStyle3', 'J4_primaryStyle4', 'J4_subStyle', 'J4_subStyle1', 'J4_subStyle2', 'J4_item1', 'J4_item2', 'J4_item3', 'J4_item4', 'J4_item5', 'J4_item6', 'J4_item7', 'J4_teamId', 'J4_win'], ['J5_summonerName', 'J5_summonerId', 'J5_puuid', 'J5_championId', 'J5_championName', 'J5_lane', 'J5_role', 'J5_kills', 'J5_deaths', 'J5_assists', 'J5_summonerSpell1', 'J5_summonerSpell2', 'J5_primaryStyle', 'J5_primaryStyle1', 'J5_primaryStyle2', 'J5_primaryStyle3', 'J5_primaryStyle4', 'J5_subStyle', 'J5_subStyle1', 'J5_subStyle2', 'J5_item1', 'J5_item2', 'J5_item3', 'J5_item4', 'J5_item5', 'J5_item6', 'J5_item7', 'J5_teamId', 'J5_win'], ['J6_summonerName', 'J6_summonerId', 'J6_puuid', 'J6_championId', 'J6_championName', 'J6_lane', 'J6_role', 'J6_kills', 'J6_deaths', 'J6_assists', 'J6_summonerSpell1', 'J6_summonerSpell2', 'J6_primaryStyle', 'J6_primaryStyle1', 'J6_primaryStyle2', 'J6_primaryStyle3', 'J6_primaryStyle4', 'J6_subStyle', 'J6_subStyle1', 'J6_subStyle2', 'J6_item1', 'J6_item2', 'J6_item3', 'J6_item4', 'J6_item5', 'J6_item6', 'J6_item7', 'J6_teamId', 'J6_win'], ['J7_summonerName', 'J7_summonerId', 'J7_puuid', 'J7_championId', 'J7_championName', 'J7_lane', 'J7_role', 'J7_kills', 'J7_deaths', 'J7_assists', 'J7_summonerSpell1', 'J7_summonerSpell2', 'J7_primaryStyle', 'J7_primaryStyle1', 'J7_primaryStyle2', 'J7_primaryStyle3', 'J7_primaryStyle4', 'J7_subStyle', 'J7_subStyle1', 'J7_subStyle2', 'J7_item1', 'J7_item2', 'J7_item3', 'J7_item4', 'J7_item5', 'J7_item6', 'J7_item7', 'J7_teamId', 'J7_win'], ['J8_summonerName', 'J8_summonerId', 'J8_puuid', 'J8_championId', 'J8_championName', 'J8_lane', 'J8_role', 'J8_kills', 'J8_deaths', 'J8_assists', 'J8_summonerSpell1', 'J8_summonerSpell2', 'J8_primaryStyle', 'J8_primaryStyle1', 'J8_primaryStyle2', 'J8_primaryStyle3', 'J8_primaryStyle4', 'J8_subStyle', 'J8_subStyle1', 'J8_subStyle2', 'J8_item1', 'J8_item2', 'J8_item3', 'J8_item4', 'J8_item5', 'J8_item6', 'J8_item7', 'J8_teamId', 'J8_win'], ['J9_summonerName', 'J9_summonerId', 'J9_puuid', 'J9_championId', 'J9_championName', 'J9_lane', 'J9_role', 'J9_kills', 'J9_deaths', 'J9_assists', 'J9_summonerSpell1', 'J9_summonerSpell2', 'J9_primaryStyle', 'J9_primaryStyle1', 'J9_primaryStyle2', 'J9_primaryStyle3', 'J9_primaryStyle4', 'J9_subStyle', 'J9_subStyle1', 'J9_subStyle2', 'J9_item1', 'J9_item2', 'J9_item3', 'J9_item4', 'J9_item5', 'J9_item6', 'J9_item7', 'J9_teamId', ...

# %%
for id_match in list_match_data.json() :
    final_match_url = match_url + id_match + '?api_key=' + api_key
    match = requests.get(final_match_url)
    match_info = [match.json()['metadata']['matchId'], match.json()['info']['gameMode'], match.json()['info']['mapId']]
    for k in range(0, 10):
        match_info.append([match.json()['info']['participants'][k]['summonerName'], match.json()['info']['participants'][k]['summonerId'], match.json()['info']['participants'][k]['puuid'],
                           match.json()['info']['participants'][k]['championId'], match.json()['info']['participants'][k]['championName'], 
                           match.json()['info']['participants'][k]['lane'], match.json()['info']['participants'][k]['role'],
                           match.json()['info']['participants'][k]['kills'], match.json()['info']['participants'][k]['deaths'], match.json()['info']['participants'][k]['assists'],
                           match.json()['info']['participants'][k]['summoner1Id'], match.json()['info']['participants'][k]['summoner2Id'], 
                           match.json()['info']['participants'][k]['perks']['styles'][0]['style'], match.json()['info']['participants'][k]['perks']['styles'][0]['selections'][0]['perk'],
                           match.json()['info']['participants'][k]['perks']['styles'][0]['selections'][1]['perk'], match.json()['info']['participants'][k]['perks']['styles'][0]['selections'][2]['perk'],
                           match.json()['info']['participants'][k]['perks']['styles'][0]['selections'][3]['perk'], match.json()['info']['participants'][k]['perks']['styles'][1]['style'],
                           match.json()['info']['participants'][k]['perks']['styles'][1]['selections'][0]['perk'], match.json()['info']['participants'][k]['perks']['styles'][1]['selections'][1]['perk'], 
                           match.json()['info']['participants'][k]['item0'], match.json()['info']['participants'][k]['item1'], match.json()['info']['participants'][k]['item2'], 
                           match.json()['info']['participants'][k]['item3'], match.json()['info']['participants'][k]['item4'], match.json()['info']['participants'][k]['item5'],
                           match.json()['info']['participants'][k]['item6'], match.json()['info']['participants'][k]['teamId'], match.json()['info']['participants'][k]['win']])
    match_database.append(match_info)

# %%
print(match_database)
# Out:
# [['matchId', 'gameMode', 'mapId', ['J1_summonerName', 'J1_summonerId', 'J1_puuid', 'J1_championId', 'J1_championName', 'J1_lane', 'J1_role', 'J1_kills', 'J1_deaths', 'J1_assists', 'J1_summonerSpell1', 'J1_summonerSpell2', 'J1_primaryStyle', 'J1_primaryStyle1', 'J1_primaryStyle2', 'J1_primaryStyle3', 'J1_primaryStyle4', 'J1_subStyle', 'J1_subStyle1', 'J1_subStyle2', 'J1_item1', 'J1_item2', 'J1_item3', 'J1_item4', 'J1_item5', 'J1_item6', 'J1_item7', 'J1_teamId', 'J1_win'], ['J2_summonerName', 'J2_summonerId', 'J2_puuid', 'J2_championId', 'J2_championName', 'J2_lane', 'J2_role', 'J2_kills', 'J2_deaths', 'J2_assists', 'J2_summonerSpell1', 'J2_summonerSpell2', 'J2_primaryStyle', 'J2_primaryStyle1', 'J2_primaryStyle2', 'J2_primaryStyle3', 'J2_primaryStyle4', 'J2_subStyle', 'J2_subStyle1', 'J2_subStyle2', 'J2_item1', 'J2_item2', 'J2_item3', 'J2_item4', 'J2_item5', 'J2_item6', 'J2_item7', 'J2_teamId', 'J2_win'], ['J3_summonerName', 'J3_summonerId', 'J3_puuid', 'J3_championId', 'J3_championName', 'J3_lane', 'J3_role', 'J3_kills', 'J3_deaths', 'J3_assists', 'J3_summonerSpell1', 'J3_summonerSpell2', 'J3_primaryStyle', 'J3_primaryStyle1', 'J3_primaryStyle2', 'J3_primaryStyle3', 'J3_primaryStyle4', 'J3_subStyle', 'J3_subStyle1', 'J3_subStyle2', 'J3_item1', 'J3_item2', 'J3_item3', 'J3_item4', 'J3_item5', 'J3_item6', 'J3_item7', 'J3_teamId', 'J3_win'], ['J4_summonerName', 'J4_summonerId', 'J4_puuid', 'J4_championId', 'J4_championName', 'J4_lane', 'J4_role', 'J4_kills', 'J4_deaths', 'J4_assists', 'J4_summonerSpell1', 'J4_summonerSpell2', 'J4_primaryStyle', 'J4_primaryStyle1', 'J4_primaryStyle2', 'J4_primaryStyle3', 'J4_primaryStyle4', 'J4_subStyle', 'J4_subStyle1', 'J4_subStyle2', 'J4_item1', 'J4_item2', 'J4_item3', 'J4_item4', 'J4_item5', 'J4_item6', 'J4_item7', 'J4_teamId', 'J4_win'], ['J5_summonerName', 'J5_summonerId', 'J5_puuid', 'J5_championId', 'J5_championName', 'J5_lane', 'J5_role', 'J5_kills', 'J5_deaths', 'J5_assists', 'J5_summonerSpell1', 'J5_summonerSpell2', 'J5_primaryStyle', 'J5_primaryStyle1', 'J5_primaryStyle2', 'J5_primaryStyle3', 'J5_primaryStyle4', 'J5_subStyle', 'J5_subStyle1', 'J5_subStyle2', 'J5_item1', 'J5_item2', 'J5_item3', 'J5_item4', 'J5_item5', 'J5_item6', 'J5_item7', 'J5_teamId', 'J5_win'], ['J6_summonerName', 'J6_summonerId', 'J6_puuid', 'J6_championId', 'J6_championName', 'J6_lane', 'J6_role', 'J6_kills', 'J6_deaths', 'J6_assists', 'J6_summonerSpell1', 'J6_summonerSpell2', 'J6_primaryStyle', 'J6_primaryStyle1', 'J6_primaryStyle2', 'J6_primaryStyle3', 'J6_primaryStyle4', 'J6_subStyle', 'J6_subStyle1', 'J6_subStyle2', 'J6_item1', 'J6_item2', 'J6_item3', 'J6_item4', 'J6_item5', 'J6_item6', 'J6_item7', 'J6_teamId', 'J6_win'], ['J7_summonerName', 'J7_summonerId', 'J7_puuid', 'J7_championId', 'J7_championName', 'J7_lane', 'J7_role', 'J7_kills', 'J7_deaths', 'J7_assists', 'J7_summonerSpell1', 'J7_summonerSpell2', 'J7_primaryStyle', 'J7_primaryStyle1', 'J7_primaryStyle2', 'J7_primaryStyle3', 'J7_primaryStyle4', 'J7_subStyle', 'J7_subStyle1', 'J7_subStyle2', 'J7_item1', 'J7_item2', 'J7_item3', 'J7_item4', 'J7_item5', 'J7_item6', 'J7_item7', 'J7_teamId', 'J7_win'], ['J8_summonerName', 'J8_summonerId', 'J8_puuid', 'J8_championId', 'J8_championName', 'J8_lane', 'J8_role', 'J8_kills', 'J8_deaths', 'J8_assists', 'J8_summonerSpell1', 'J8_summonerSpell2', 'J8_primaryStyle', 'J8_primaryStyle1', 'J8_primaryStyle2', 'J8_primaryStyle3', 'J8_primaryStyle4', 'J8_subStyle', 'J8_subStyle1', 'J8_subStyle2', 'J8_item1', 'J8_item2', 'J8_item3', 'J8_item4', 'J8_item5', 'J8_item6', 'J8_item7', 'J8_teamId', 'J8_win'], ['J9_summonerName', 'J9_summonerId', 'J9_puuid', 'J9_championId', 'J9_championName', 'J9_lane', 'J9_role', 'J9_kills', 'J9_deaths', 'J9_assists', 'J9_summonerSpell1', 'J9_summonerSpell2', 'J9_primaryStyle', 'J9_primaryStyle1', 'J9_primaryStyle2', 'J9_primaryStyle3', 'J9_primaryStyle4', 'J9_subStyle', 'J9_subStyle1', 'J9_subStyle2', 'J9_item1', 'J9_item2', 'J9_item3', 'J9_item4', 'J9_item5', 'J9_item6', 'J9_item7', 'J9_teamId', ...

# %% [markdown]
# ## Récupération des données annexes

# %% [markdown]
# N'oublions pas que certaines données ne sont pas directement accessibles par les services de l'API LoL, comme les items ou les champions. Cependant nous pouvons enregistrer le fichier et les importer (nous n'aurons pas à l'update durant toute la durée du projet).

# %%
f = open('database_json/champion.json') #mettez votre chemin
champions = json.load(f)

# %%
champion_database = [['id', 'key']]
for champ in champions['data']:
    infos = [champions['data'][champ]['id'], int(champions['data'][champ]['key'])]
    champion_database.append(infos)

# %%
print(champion_database)
# Out:
# [['id', 'key'], ['Aatrox', 266], ['Ahri', 103], ['Akali', 84], ['Akshan', 166], ['Alistar', 12], ['Amumu', 32], ['Anivia', 34], ['Annie', 1], ['Aphelios', 523], ['Ashe', 22], ['AurelionSol', 136], ['Azir', 268], ['Bard', 432], ['Belveth', 200], ['Blitzcrank', 53], ['Brand', 63], ['Braum', 201], ['Caitlyn', 51], ['Camille', 164], ['Cassiopeia', 69], ['Chogath', 31], ['Corki', 42], ['Darius', 122], ['Diana', 131], ['Draven', 119], ['DrMundo', 36], ['Ekko', 245], ['Elise', 60], ['Evelynn', 28], ['Ezreal', 81], ['Fiddlesticks', 9], ['Fiora', 114], ['Fizz', 105], ['Galio', 3], ['Gangplank', 41], ['Garen', 86], ['Gnar', 150], ['Gragas', 79], ['Graves', 104], ['Gwen', 887], ['Hecarim', 120], ['Heimerdinger', 74], ['Illaoi', 420], ['Irelia', 39], ['Ivern', 427], ['Janna', 40], ['JarvanIV', 59], ['Jax', 24], ['Jayce', 126], ['Jhin', 202], ['Jinx', 222], ['Kaisa', 145], ['Kalista', 429], ['Karma', 43], ['Karthus', 30], ['Kassadin', 38], ['Katarina', 55], ['Kayle', 10], ['Kayn', 141], ['Kennen', 85], ['Khazix', 121], ['Kindred', 203], ['Kled', 240], ['KogMaw', 96], ['KSante', 897], ['Leblanc', 7], ['LeeSin', 64], ['Leona', 89], ['Lillia', 876], ['Lissandra', 127], ['Lucian', 236], ['Lulu', 117], ['Lux', 99], ['Malphite', 54], ['Malzahar', 90], ['Maokai', 57], ['MasterYi', 11], ['Milio', 902], ['MissFortune', 21], ['MonkeyKing', 62], ['Mordekaiser', 82], ['Morgana', 25], ['Naafiri', 950], ['Nami', 267], ['Nasus', 75], ['Nautilus', 111], ['Neeko', 518], ['Nidalee', 76], ['Nilah', 895], ['Nocturne', 56], ['Nunu', 20], ['Olaf', 2], ['Orianna', 61], ['Ornn', 516], ['Pantheon', 80], ['Poppy', 78], ['Pyke', 555], ['Qiyana', 246], ['Quinn', 133], ['Rakan', 497], ['Rammus', 33], ['RekSai', 421], ['Rell', 526], ['Renata', 888], ['Renekton', 58], ['Rengar', 107], ['Riven', 92], ['Rumble', 68], ['Ryze', 13], ['Samira', 360], ['Sejuani', 113], ['Senna', 235], ['Seraphine', 147], ['Sett', 875], ['Shaco', 35], ['Shen', 98], ['Shyvana', 102], ['Singed', 27], ['Sion', 14], ['Sivir', 15], ['Skarner', 72], ['Sona', 37], ['Soraka', 16], ['Swain', 50], ['Sylas', 517], ['Syndra', 134], ['TahmKench', 223], ['Taliyah', 163], ['Talon', 91], ['Taric', 44], ['Teemo', 17], ['Thresh', 412], ['Tristana', 18], ['Trundle', 48], ['Tryndamere', 23], ['TwistedFate', 4], ['Twitch', 29], ['Udyr', 77], ['Urgot', 6], ['Varus', 110], ['Vayne', 67], ['Veigar', 45], ['Velkoz', 161], ['Vex', 711], ['Vi', 254], ['Viego', 234], ['Viktor', 112], ['Vladimir', 8], ['Volibear', 106], ['Warwick', 19], ['Xayah', 498], ['Xerath', 101], ['XinZhao', 5], ['Yasuo', 157], ['Yone', 777], ['Yorick', 83], ['Yuumi', 350], ['Zac', 154], ['Zed', 238], ['Zeri', 221], ['Ziggs', 115], ['Zilean', 26], ['Zoe', 142], ['Zyra', 143]]

# %% [markdown]
# Le code est volontairement incomplet, pas optimisé. Il ne doit vous servir que pour vous donner les premiers pas sur l'utilisation de l'API.
#
# Certaines données sont récupérées mais pas forcément intéressantes, d'autres ne sont pas récupérées mais peuvent vous être utiles. Veuillez l'adapter à votre besoin.
